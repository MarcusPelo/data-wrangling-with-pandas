# %%
import pandas as pd

google = pd.read_csv('data/google_june_2020.csv', index_col = 0)
msft = pd.read_csv('data/msft_june_2020.csv', index_col = 0)
amzn = pd.read_csv('data/amzn_june_2020.csv', index_col = 0)

# %%
google.info
# Out:
# <bound method DataFrame.info of           Date        Close   Volume Symbol
# 0   2020-06-01  1434.869995  1258100  GOOGL
# 1   2020-06-02  1442.310059  1172100  GOOGL
# 2   2020-06-03  1439.250000  1386600  GOOGL
# 3   2020-06-04  1414.300049  1349100  GOOGL
# 4   2020-06-05  1440.020020  2132100  GOOGL
# 5   2020-06-08  1448.040039  1693900  GOOGL
# 6   2020-06-09  1452.079956  1681200  GOOGL
# 7   2020-06-10  1464.699951  1588100  GOOGL
# 8   2020-06-11  1401.900024  2357200  GOOGL
# 9   2020-06-12  1412.920044  1832900  GOOGL
# 10  2020-06-15  1420.739990  1523400  GOOGL
# 11  2020-06-16  1446.469971  1532400  GOOGL
# 12  2020-06-17  1452.540039  1528300  GOOGL
# 13  2020-06-18  1434.119995  1743100  GOOGL
# 14  2020-06-19  1424.640015  2639200  GOOGL
# 15  2020-06-22  1450.660034  1472100  GOOGL
# 16  2020-06-23  1463.979980  1887600  GOOGL
# 17  2020-06-24  1432.699951  1579600  GOOGL
# 18  2020-06-25  1441.099976  1197900  GOOGL
# 19  2020-06-26  1362.540039  4882000  GOOGL
# 20  2020-06-29  1397.170044  2253700  GOOGL
# 21  2020-06-30  1418.050049  2014300  GOOGL>

# %%
google.head(2)
# Out:
#          Date        Close   Volume Symbol
# 0  2020-06-01  1434.869995  1258100  GOOGL
# 1  2020-06-02  1442.310059  1172100  GOOGL

# %% [markdown]
# ### Concatenation of Tidy Data Source

# %%
all_df = pd.DataFrame()
all_df = all_df.append([google, msft, amzn])
# Out:
# C:\Users\Marcus\AppData\Local\Temp\ipykernel_18940\308056997.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_df = all_df.append([google, msft, amzn])

# %%
all_df.info()
all_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66 entries, 0 to 21
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    66 non-null     object
#  1   Close   66 non-null     float64
#  2   Volume  66 non-null     int64
#  3   Symbol  66 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 2.6+ KB
#          Date        Close   Volume Symbol
# 0  2020-06-01  1434.869995  1258100  GOOGL
# 1  2020-06-02  1442.310059  1172100  GOOGL
# 2  2020-06-03  1439.250000  1386600  GOOGL
# 3  2020-06-04  1414.300049  1349100  GOOGL
# 4  2020-06-05  1440.020020  2132100  GOOGL

# %%
all_df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Concatenation of Tidy Data Source - pd.concat()

# %%
all_df = pd.concat([google, msft, amzn])
all_df.reset_index(drop=True, inplace=True)
all_df.head()
# Out:
#          Date        Close   Volume Symbol
# 0  2020-06-01  1434.869995  1258100  GOOGL
# 1  2020-06-02  1442.310059  1172100  GOOGL
# 2  2020-06-03  1439.250000  1386600  GOOGL
# 3  2020-06-04  1414.300049  1349100  GOOGL
# 4  2020-06-05  1440.020020  2132100  GOOGL

# %%
all_df.shape
# Out:
# (66, 4)

# %% [markdown]
# ### Lecture 4 - Multi-level Indexing

# %%
google = pd.read_csv('data/google_june_2020.csv', index_col = 0)
msft = pd.read_csv('data/msft_june_2020.csv', index_col = 0)
amzn = pd.read_csv('data/amzn_june_2020.csv', index_col = 0)
all_df = pd.concat([google, msft, amzn])
all_df.reset_index(drop=True, inplace=True)
all_df.head()
# Out:
#          Date        Close   Volume Symbol
# 0  2020-06-01  1434.869995  1258100  GOOGL
# 1  2020-06-02  1442.310059  1172100  GOOGL
# 2  2020-06-03  1439.250000  1386600  GOOGL
# 3  2020-06-04  1414.300049  1349100  GOOGL
# 4  2020-06-05  1440.020020  2132100  GOOGL

# %%
all_df.set_index(['Symbol', 'Date'], inplace=True)

# %%
all_df.head(2)
# Out:
#                          Close   Volume
# Symbol Date
# GOOGL  2020-06-01  1434.869995  1258100
#        2020-06-02  1442.310059  1172100

# %%
all_df.sort_index(inplace=True)
all_df.head()
# Out:
#                          Close   Volume
# Symbol Date
# AMZN   2020-06-01  2471.040039  2928900
#        2020-06-02  2472.409912  2529900
#        2020-06-03  2478.399902  2671000
#        2020-06-04  2460.600098  2948700
#        2020-06-05  2483.000000  3306400

# %%
all_df.loc[('AMZN', '2020-06-01'),:]
# Out:
# Close     2.471040e+03
# Volume    2.928900e+06
# Name: (AMZN, 2020-06-01), dtype: float64

# %%
all_df.loc[('AMZN', '2020-06-01'),'Close']
# Out:
# 2471.0400390625

# %%
all_df.index.levels
# Out:
# FrozenList([['AMZN', 'GOOGL', 'MSFT'], ['2020-06-01', '2020-06-02', '2020-06-03', '2020-06-04', '2020-06-05', '2020-06-08', '2020-06-09', '2020-06-10', '2020-06-11', '2020-06-12', '2020-06-15', '2020-06-16', '2020-06-17', '2020-06-18', '2020-06-19', '2020-06-22', '2020-06-23', '2020-06-24', '2020-06-25', '2020-06-26', '2020-06-29', '2020-06-30']])

# %%
all_df.index.levels[0]
# Out:
# Index(['AMZN', 'GOOGL', 'MSFT'], dtype='object', name='Symbol')

# %%
all_df.index.levels[1]
# Out:
# Index(['2020-06-01', '2020-06-02', '2020-06-03', '2020-06-04', '2020-06-05',
#        '2020-06-08', '2020-06-09', '2020-06-10', '2020-06-11', '2020-06-12',
#        '2020-06-15', '2020-06-16', '2020-06-17', '2020-06-18', '2020-06-19',
#        '2020-06-22', '2020-06-23', '2020-06-24', '2020-06-25', '2020-06-26',
#        '2020-06-29', '2020-06-30'],
#       dtype='object', name='Date')

# %%
all_df.loc[(['AMZN','GOOGL'], '2020-06-01'),'Close']
# Out:
# Symbol  Date
# AMZN    2020-06-01    2471.040039
# GOOGL   2020-06-01    1434.869995
# Name: Close, dtype: float64

# %% [markdown]
# ### Lecture 5 - Merging Tidy Data

# %%
google = pd.read_csv('data/google_june_2020.csv', index_col = 0)
msft = pd.read_csv('data/msft_june_2020.csv', index_col = 0)
amzn = pd.read_csv('data/amzn_june_2020.csv', index_col = 0)
all_df = pd.concat([google, msft, amzn])
all_df.reset_index(drop=True, inplace=True)
all_df.head()
# Out:
#          Date        Close   Volume Symbol
# 0  2020-06-01  1434.869995  1258100  GOOGL
# 1  2020-06-02  1442.310059  1172100  GOOGL
# 2  2020-06-03  1439.250000  1386600  GOOGL
# 3  2020-06-04  1414.300049  1349100  GOOGL
# 4  2020-06-05  1440.020020  2132100  GOOGL

# %%
all_df_columns = pd.concat([google, msft, amzn], axis = 1)

# %%
all_df_columns.head()
# Out:
#          Date        Close   Volume Symbol        Date       Close    Volume  \
# 0  2020-06-01  1434.869995  1258100  GOOGL  2020-06-01  182.830002  22622400
# 1  2020-06-02  1442.310059  1172100  GOOGL  2020-06-02  184.910004  30794600
# 2  2020-06-03  1439.250000  1386600  GOOGL  2020-06-03  185.360001  27311000
# 3  2020-06-04  1414.300049  1349100  GOOGL  2020-06-04  182.919998  28761800
# 4  2020-06-05  1440.020020  2132100  GOOGL  2020-06-05  187.199997  39893600
#
#   Symbol        Date        Close   Volume Symbol
# 0   MSFT  2020-06-01  2471.040039  2928900   AMZN
# 1   MSFT  2020-06-02  2472.409912  2529900   AMZN
# 2   MSFT  2020-06-03  2478.399902  2671000   AMZN
# 3   MSFT  2020-06-04  2460.600098  2948700   AMZN
# 4   MSFT  2020-06-05  2483.000000  3306400   AMZN

# %%
pd.concat([google, msft, amzn], axis = 1, verify_integrity=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Marcus\gitpelo\data-wrangling-with-pandas-jupyter\data-wrangling-with-pandas.ipynb Célula: 26 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Marcus/gitpelo/data-wrangling-with-pandas-jupyter/data-wrangling-with-pandas.ipynb#ch0000025?line=0'>1</a> pd.concat([google, msft, amzn], axis = 1, verify_integrity=True)
#
# File c:\Users\Marcus\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\Marcus\anaconda3\lib\site-packages\pandas\core\reshape\concat.py:347, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     143 @deprecate_nonkeyword_arguments(version=None, allowed_args=["objs"])
#     144 def concat(
#     145     objs: Iterable[NDFrame] | Mapping[Hashable, NDFrame],
#    (...)
#     154     copy: bool = True,
#     155 ) -> DataFrame | Series:
#     156     """
#     157     Concatenate pandas objects along a particular axis with optional set logic
#     158     along the other axes.
#    (...)
#     345     ValueError: Indexes have overlapping values: ['a']
#     346     """
# --> 347     op = _Concatenator(
#     348         objs,
#     349         axis=axis,
#     350         ignore_index=ignore_index,
#     351         join=join,
#     352         keys=keys,
#     353         levels=levels,
#     354         names=names,
#     355         verify_integrity=verify_integrity,
#     356         copy=copy,
#     357         sort=sort,
#     358     )
#     360     return op.get_result()
#
# File c:\Users\Marcus\anaconda3\lib\site-packages\pandas\core\reshape\concat.py:542, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     539 self.verify_integrity = verify_integrity
#     540 self.copy = copy
# --> 542 self.new_axes = self._get_new_axes()
#
# File c:\Users\Marcus\anaconda3\lib\site-packages\pandas\core\reshape\concat.py:612, in _Concatenator._get_new_axes(self)
#     610 def _get_new_axes(self) -> list[Index]:
#     611     ndim = self._get_result_dim()
# --> 612     return [
#     613         self._get_concat_axis if i == self.bm_axis else self._get_comb_axis(i)
#     614         for i in range(ndim)
#     615     ]
#
# File c:\Users\Marcus\anaconda3\lib\site-packages\pandas\core\reshape\concat.py:613, in <listcomp>(.0)
#     610 def _get_new_axes(self) -> list[Index]:
#     611     ndim = self._get_result_dim()
#     612     return [
# --> 613         self._get_concat_axis if i == self.bm_axis else self._get_comb_axis(i)
#     614         for i in range(ndim)
#     615     ]
#
# File c:\Users\Marcus\anaconda3\lib\site-packages\pandas\_libs\properties.pyx:37, in pandas._libs.properties.CachedProperty.__get__()
#
# File c:\Users\Marcus\anaconda3\lib\site-packages\pandas\core\reshape\concat.py:674, in _Concatenator._get_concat_axis(self)
#     669 else:
#     670     concat_axis = _make_concat_multiindex(
#     671         indexes, self.keys, self.levels, self.names
#     672     )
# --> 674 self._maybe_check_integrity(concat_axis)
#     676 return concat_axis
#
# File c:\Users\Marcus\anaconda3\lib\site-packages\pandas\core\reshape\concat.py:682, in _Concatenator._maybe_check_integrity(self, concat_index)
#     680 if not concat_index.is_unique:
#     681     overlap = concat_index[concat_index.duplicated()].unique()
# --> 682     raise ValueError(f"Indexes have overlapping values: {overlap}")
#
# ValueError: Indexes have overlapping values: Index(['Date', 'Close', 'Volume', 'Symbol'], dtype='object')

# %%
def new_agg_df(df):
    
    my_list = []
    symbol = df['Symbol'].drop_duplicates().values[0]
    df.drop(['Symbol'], axis=1, inplace=True)
    df.set_index('Date', inplace=True)
    my_list = [symbol+'_'+elem for elem in df.columns]
    df.columns = my_list


    return df

# %%
amzn_agg = new_agg_df(amzn)
msft_agg = new_agg_df(msft)
google_agg = new_agg_df(google)

# %%
amzn_agg.head()
# Out:
#              AMZN_Close  AMZN_Volume
# Date
# 2020-06-01  2471.040039      2928900
# 2020-06-02  2472.409912      2529900
# 2020-06-03  2478.399902      2671000
# 2020-06-04  2460.600098      2948700
# 2020-06-05  2483.000000      3306400

# %%
amzn_agg.reset_index().merge(msft_agg.reset_index(), on = 'Date').head()
# Out:
#          Date   AMZN_Close  AMZN_Volume  MSFT_Close  MSFT_Volume
# 0  2020-06-01  2471.040039      2928900  182.830002     22622400
# 1  2020-06-02  2472.409912      2529900  184.910004     30794600
# 2  2020-06-03  2478.399902      2671000  185.360001     27311000
# 3  2020-06-04  2460.600098      2948700  182.919998     28761800
# 4  2020-06-05  2483.000000      3306400  187.199997     39893600

# %%
amzn_agg.reset_index().merge(msft_agg.reset_index(), left_on = 'Date', right_on = 'Date', how='inner').head()
# Out:
#          Date   AMZN_Close  AMZN_Volume  MSFT_Close  MSFT_Volume
# 0  2020-06-01  2471.040039      2928900  182.830002     22622400
# 1  2020-06-02  2472.409912      2529900  184.910004     30794600
# 2  2020-06-03  2478.399902      2671000  185.360001     27311000
# 3  2020-06-04  2460.600098      2948700  182.919998     28761800
# 4  2020-06-05  2483.000000      3306400  187.199997     39893600

# %%
all_df_agg = amzn_agg.merge(msft_agg, left_index=True, right_index=True).merge(
    google_agg,  left_index=True, right_index=True
)

all_df_agg.head()
# Out:
#              AMZN_Close  AMZN_Volume  MSFT_Close  MSFT_Volume  GOOGL_Close  \
# Date
# 2020-06-01  2471.040039      2928900  182.830002     22622400  1434.869995
# 2020-06-02  2472.409912      2529900  184.910004     30794600  1442.310059
# 2020-06-03  2478.399902      2671000  185.360001     27311000  1439.250000
# 2020-06-04  2460.600098      2948700  182.919998     28761800  1414.300049
# 2020-06-05  2483.000000      3306400  187.199997     39893600  1440.020020
#
#             GOOGL_Volume
# Date
# 2020-06-01       1258100
# 2020-06-02       1172100
# 2020-06-03       1386600
# 2020-06-04       1349100
# 2020-06-05       2132100

# %% [markdown]
# ### Lecture 6 - Transformation of a Dataset

# %%
google = pd.read_csv('data/google_june_2020.csv', index_col = 0)
msft = pd.read_csv('data/msft_june_2020.csv', index_col = 0)
amzn = pd.read_csv('data/amzn_june_2020.csv', index_col = 0)
all_df = pd.concat([google, msft, amzn])
all_df.reset_index(drop=True, inplace=True)
all_df.head()
# Out:
#          Date        Close   Volume Symbol
# 0  2020-06-01  1434.869995  1258100  GOOGL
# 1  2020-06-02  1442.310059  1172100  GOOGL
# 2  2020-06-03  1439.250000  1386600  GOOGL
# 3  2020-06-04  1414.300049  1349100  GOOGL
# 4  2020-06-05  1440.020020  2132100  GOOGL

# %%
pivot_clone = all_df.pivot(
    index = 'Date',
    columns = 'Symbol',
    values = 'Close'
).sort_index()

# %%
pivot_clone.head()
# Out:
# Symbol             AMZN        GOOGL        MSFT
# Date
# 2020-06-01  2471.040039  1434.869995  182.830002
# 2020-06-02  2472.409912  1442.310059  184.910004
# 2020-06-03  2478.399902  1439.250000  185.360001
# 2020-06-04  2460.600098  1414.300049  182.919998
# 2020-06-05  2483.000000  1440.020020  187.199997

# %%
pivot_clone_volume = all_df.pivot(
    index = 'Date',
    columns = 'Symbol',

).sort_index()
pivot_clone_volume.head()
# Out:
#                   Close                            Volume
# Symbol             AMZN        GOOGL        MSFT     AMZN    GOOGL      MSFT
# Date
# 2020-06-01  2471.040039  1434.869995  182.830002  2928900  1258100  22622400
# 2020-06-02  2472.409912  1442.310059  184.910004  2529900  1172100  30794600
# 2020-06-03  2478.399902  1439.250000  185.360001  2671000  1386600  27311000
# 2020-06-04  2460.600098  1414.300049  182.919998  2948700  1349100  28761800
# 2020-06-05  2483.000000  1440.020020  187.199997  3306400  2132100  39893600

# %%
another_df = all_df.set_index(['Symbol','Date'])
unstacked_df = another_df.unstack(level = 'Symbol')
unstacked_df.head()
# Out:
#                   Close                            Volume
# Symbol             AMZN        GOOGL        MSFT     AMZN    GOOGL      MSFT
# Date
# 2020-06-01  2471.040039  1434.869995  182.830002  2928900  1258100  22622400
# 2020-06-02  2472.409912  1442.310059  184.910004  2529900  1172100  30794600
# 2020-06-03  2478.399902  1439.250000  185.360001  2671000  1386600  27311000
# 2020-06-04  2460.600098  1414.300049  182.919998  2948700  1349100  28761800
# 2020-06-05  2483.000000  1440.020020  187.199997  3306400  2132100  39893600

# %%
unstacked_df.stack(level='Symbol').head()
# Out:
#                          Close    Volume
# Date       Symbol
# 2020-06-01 AMZN    2471.040039   2928900
#            GOOGL   1434.869995   1258100
#            MSFT     182.830002  22622400
# 2020-06-02 AMZN    2472.409912   2529900
#            GOOGL   1442.310059   1172100

# %%
stacked_df = unstacked_df.stack(level = 'Symbol')
swapped_df = stacked_df.swaplevel('Symbol', 'Date')
swapped_df.head()
# Out:
#                          Close    Volume
# Symbol Date
# AMZN   2020-06-01  2471.040039   2928900
# GOOGL  2020-06-01  1434.869995   1258100
# MSFT   2020-06-01   182.830002  22622400
# AMZN   2020-06-02  2472.409912   2529900
# GOOGL  2020-06-02  1442.310059   1172100

# %%
swapped_df.sort_index().head()
# Out:
#                          Close   Volume
# Symbol Date
# AMZN   2020-06-01  2471.040039  2928900
#        2020-06-02  2472.409912  2529900
#        2020-06-03  2478.399902  2671000
#        2020-06-04  2460.600098  2948700
#        2020-06-05  2483.000000  3306400

# %% [markdown]
# ### Melting with Pandas

# %%
all_df.melt(id_vars=['Symbol','Date'])
# Out:
#     Symbol        Date variable         value
# 0    GOOGL  2020-06-01    Close  1.434870e+03
# 1    GOOGL  2020-06-02    Close  1.442310e+03
# 2    GOOGL  2020-06-03    Close  1.439250e+03
# 3    GOOGL  2020-06-04    Close  1.414300e+03
# 4    GOOGL  2020-06-05    Close  1.440020e+03
# ..     ...         ...      ...           ...
# 127   AMZN  2020-06-24   Volume  4.526600e+06
# 128   AMZN  2020-06-25   Volume  2.968700e+06
# 129   AMZN  2020-06-26   Volume  6.500800e+06
# 130   AMZN  2020-06-29   Volume  4.223400e+06
# 131   AMZN  2020-06-30   Volume  3.769700e+06
#
# [132 rows x 4 columns]

# %% [markdown]
# ### Aggregating Results with Pandas

# %%
pivot_close = all_df.pivot(
    index = 'Date',
    columns = 'Symbol',
    values = 'Close'
).sort_index().reset_index()


mean_pivot = pd.DataFrame()
mean_pivot['Symbol'] = pivot_close['Symbol'].to_list()
mean_pivot['average_price'] = pivot_close.set_index('Symbol').apply(
    lambda x: x.mean(), axis = 1
).to_list()

mean_pivot.set_index('Symbol')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Marcus\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\Marcus\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Marcus\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Symbol'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\Marcus\gitpelo\data-wrangling-with-pandas-jupyter\data-wrangling-with-pandas.ipynb Célula: 45 in <cell line: 9>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Marcus/gitpelo/data-wrangling-with-pandas-jupyter/data-wrangling-with-pandas.ipynb#ch0000044?line=0'>1</a> pivot_close = all_df.pivot(
#       <a href='vscode-notebook-cell:/c%3A/Users/Marcus/gitpelo/data-wrangling-with-pandas-jupyter/data-wrangling-with-pandas.ipynb#ch0000044?line=1'>2</a>     index = 'Date',
#       <a href='vscode-notebook-cell:/c%3A/Users/Marcus/gitpelo/data-wrangling-with-pandas-jupyter/data-wrangling-with-pandas.ipynb#ch0000044?line=2'>3</a>     columns = 'Symbol',
#       <a href='vscode-notebook-cell:/c%3A/Users/Marcus/gitpelo/data-wrangling-with-pandas-jupyter/data-wrangling-with-pandas.ipynb#ch0000044?line=3'>4</a>     values = 'Close'
#       <a href='vscode-notebook-cell:/c%3A/Users/Marcus/gitpelo/data-wrangling-with-pandas-jupyter/data-wrangling-with-pandas.ipynb#ch0000044?line=4'>5</a> ).sort_index().reset_index()
#       <a href='vscode-notebook-cell:/c%3A/Users/Marcus/gitpelo/data-wrangling-with-pandas-jupyter/data-wrangling-with-pandas.ipynb#ch0000044?line=7'>8</a> mean_pivot = pd.DataFrame()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Marcus/gitpelo/data-wrangling-with-pandas-jupyter/data-wrangling-with-pandas.ipynb#ch0000044?line=8'>9</a> mean_pivot['Symbol'] = pivot_close['Symbol'].to_list()
#      <a href='vscode-notebook-cell:/c%3A/Users/Marcus/gitpelo/data-wrangling-with-pandas-jupyter/data-wrangling-with-pandas.ipynb#ch0000044?line=9'>10</a> mean_pivot['average_price'] = pivot_close.set_index('Symbol').apply(
#      <a href='vscode-notebook-cell:/c%3A/Users/Marcus/gitpelo/data-wrangling-with-pandas-jupyter/data-wrangling-with-pandas.ipynb#ch0000044?line=10'>11</a>     lambda x: x.mean(), axis = 1
#      <a href='vscode-notebook-cell:/c%3A/Users/Marcus/gitpelo/data-wrangling-with-pandas-jupyter/data-wrangling-with-pandas.ipynb#ch0000044?line=11'>12</a> ).to_list()
#      <a href='vscode-notebook-cell:/c%3A/Users/Marcus/gitpelo/data-wrangling-with-pandas-jupyter/data-wrangling-with-pandas.ipynb#ch0000044?line=13'>14</a> mean_pivot.set_index('Symbol')
#
# File c:\Users\Marcus\anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File c:\Users\Marcus\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Symbol'
